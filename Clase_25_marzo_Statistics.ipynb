% %%
pkg load statistics
vector= [1 2 3 4 5 8 10 8 7 4 6]
stem(vector)
size(vector)
mean(vector)
% Out:
% vector =
%
%     1    2    3    4    5    8   10    8    7    4    6
%
% ans =
%
%     1   11
%
% ans =  5.2727

% %%
min(vector) #calcular minimo
max(vector) #calcular maximo
hist(vector)
% Out:
% ans =  1
% ans =  10
